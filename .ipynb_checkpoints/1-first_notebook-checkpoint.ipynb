# %%
import numpy as np

# %%
import pandas as pd

# %%
epl_results = pd.read_csv('data/epl_results_2022-23.csv')

# %%
epl_results.head()
# Out:
#          Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0     1
# 1  06/08/2022  12:30          Fulham    Liverpool     2     2   D     1     0
# 2  06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1     0
# 3  06/08/2022  15:00           Leeds       Wolves     2     1   H     1     1
# 4  06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0     0
#
#   HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   A  ...   2    2  16  11   3   5   1   2   0   0
# 1   H  ...   3    4   7   9   4   4   2   0   0   0
# 2   H  ...   3    2  18  16   5   5   3   3   0   0
# 3   D  ...   4    6  13   9   6   4   2   0   0   0
# 4   D  ...  10    0   9  14  11   1   0   3   0   0
#
# [5 rows x 23 columns]

# %%
epl_results.columns
# Out:
# Index(['Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
epl_results = epl_results.loc[:, ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG']]

# %%
epl_results.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG'], dtype='object')

# %%
epl_results.dtypes
# Out:
# Date        object
# HomeTeam    object
# AwayTeam    object
# FTHG         int64
# FTAG         int64
# FTR         object
# HTHG         int64
# HTAG         int64
# dtype: object

# %%
epl_results['Date'] = pd.to_datetime(epl_results.Date)
# Out:
# C:\Users\Che\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Che\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Che\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/08/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
epl_results.dtypes
# Out:
# Date        datetime64[ns]
# HomeTeam            object
# AwayTeam            object
# FTHG                 int64
# FTAG                 int64
# FTR                 object
# HTHG                 int64
# HTAG                 int64
# dtype: object

# %%
epl_results.set_index('Date', inplace=True)

# %%
epl_results.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0

# %%
epl_results.index.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of DatetimeIndex(['2022-05-08', '2022-06-08', '2022-06-08', '2022-06-08',
#                '2022-06-08', '2022-06-08', '2022-06-08', '2022-07-08',
#                '2022-07-08', '2022-07-08',
#                ...
#                '2023-05-28', '2023-05-28', '2023-05-28', '2023-05-28',
#                '2023-05-28', '2023-05-28', '2023-05-28', '2023-05-28',
#                '2023-05-28', '2023-05-28'],
#               dtype='datetime64[ns]', name='Date', length=380, freq=None)>

# %%
def monthly_stats(month, team):
    correct_month = epl_results.loc[f"{month}"]
    games_played = correct_month.loc[(correct_month.HomeTeam==f"{team}") | (correct_month.AwayTeam==f"{team}")].count()[0]
    new_df = correct_month.loc[((correct_month.HomeTeam==f"{team}") & (correct_month.FTR=="H") | (correct_month.AwayTeam==f"{team}") & (correct_month.FTR=="A"))]
    games_won = new_df.FTR.count()
    home_wins = new_df.query('FTR=="H"').FTR.count()
    away_wins = new_df.query('FTR=="A"').FTR.count()
    home_goals_scored = new_df.loc[new_df.HomeTeam==team].FTHG.sum()
    away_goals_scored = new_df.loc[new_df.AwayTeam==team].FTAG.sum()
    my_new_df = pd.DataFrame({
        'month': month,
        'Team': [team],
        'GamesPlayed': [games_played],
        'GamesWon': [games_won],
        'HomeWins': [home_wins],
        'AwayWins': [away_wins],
        'HomeGoalsScored': [home_goals_scored],
        'AwayGoalsScored': [away_goals_scored]
        
        
    })
    my_new_df.set_index('month', inplace=True)
    return my_new_df
#     return new_df.loc[:, ['GamesWon', 'GamesPlayed', 'HomeWins', 'AwayWins']].T

# %%
monthly_stats("10/2022", "Arsenal")
# Out:
#             Team  GamesPlayed  GamesWon  HomeWins  AwayWins  HomeGoalsScored  \
# month
# 10/2022  Arsenal            3         2         1         1                5
#
#          AwayGoalsScored
# month
# 10/2022                1

# %% [markdown]
# # Percentage of goals scored by a big club per big clubs

# %%
import math
def monthly_big_teams_stats(month, your_team):
    all_goals = []
    teams = ['Chelsea','Man City', 'Arsenal', 'Man United', 'Tottenham', 'Newcastle', 'Liverpool']
    months = []
    games = []
    gamesWon = []
    homeWins = []
    awayWins = []
    homeGoalsScored = []
    awayGoalsScored = []
    teams2 = []
    games = []
    for team in teams:
        correct_month = epl_results.loc[f"{month}"]
        games_played = correct_month.loc[(correct_month.HomeTeam==f"{team}") | (correct_month.AwayTeam==f"{team}")].count()[0]
        new_df = correct_month.loc[((correct_month.HomeTeam==f"{team}") & (correct_month.FTR=="H") | (correct_month.AwayTeam==f"{team}") & (correct_month.FTR=="A"))]
        games_won = new_df.FTR.count()
        home_wins = new_df.query('FTR=="H"').FTR.count()
        away_wins = new_df.query('FTR=="A"').FTR.count()
        home_goals_scored = new_df.loc[new_df.HomeTeam==team].FTHG.sum()
        away_goals_scored = new_df.loc[new_df.AwayTeam==team].FTAG.sum()
        
        
        months.append(month)
        teams2.append(team)
        games.append(games_played)
        gamesWon.append(games_won)
        homeWins.append(home_wins)
        awayWins.append(away_wins)
        homeGoalsScored.append(home_goals_scored)
        awayGoalsScored.append(away_goals_scored)

    my_new_df = pd.DataFrame({
        'month': months,
        'Team': teams2,
        'GamesPlayed': games,
        'GamesWon': gamesWon,
        'HomeWins': homeWins,
        'AwayWins': awayWins,
        'HomeGoalsScored': homeGoalsScored,
        'AwayGoalsScored': awayGoalsScored
                      })
    my_new_df.set_index('month', inplace=True)
    your_team_goals = my_new_df.loc[my_new_df.Team==your_team].HomeGoalsScored.sum() + my_new_df.loc[my_new_df.Team==your_team].AwayGoalsScored.sum()
    
    
    for team in teams:
        goals = my_new_df.loc[my_new_df.Team==team].HomeGoalsScored.sum() + my_new_df.loc[my_new_df.Team==team].AwayGoalsScored.sum()
        all_goals.append(goals)
    overall = sum(all_goals)
    percentage = (your_team_goals / overall) * 100

    return f"Goals Scored by Big 7 - {overall}.\nGoals Scored by {your_team} - {your_team_goals}.\nOverall Percentage of goals by {your_team} amongst the Big 7 - {math.floor(percentage)}%."

# %%
print(monthly_big_teams_stats('05/2023', 'Man United'))
# Out:
# Goals Scored by Big 7 - 44.
# Goals Scored by Man United - 10.
# Overall Percentage of goals by Man United amongst the Big 7 - 22%.

# %%
epl_results.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0

# %%
epl_goals = epl_results.assign(
    FullTimeGoals = epl_results.FTHG + epl_results.FTAG
)

# %%
epl_goals.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0
#
#             FullTimeGoals
# Date
# 2022-05-08              2
# 2022-06-08              4
# 2022-06-08              2
# 2022-06-08              3
# 2022-06-08              2

# %%
epl_goals['FullTimeGoals_binned'] = pd.cut(
    epl_goals.FullTimeGoals, bins=3, labels=['low', 'med', 'high']
)

# %%
epl_goals
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0
# ...                    ...          ...   ...   ...  ..   ...   ...
# 2023-05-28         Everton  Bournemouth     1     0   H     0     0
# 2023-05-28           Leeds    Tottenham     1     4   A     0     1
# 2023-05-28       Leicester     West Ham     2     1   H     1     0
# 2023-05-28      Man United       Fulham     2     1   H     1     1
# 2023-05-28     Southampton    Liverpool     4     4   D     2     2
#
#             FullTimeGoals FullTimeGoals_binned
# Date
# 2022-05-08              2                  low
# ...

# %%
epl_goals[['HomeTeam', 'FullTimeGoals', 'FullTimeGoals_binned']].groupby("HomeTeam").describe()
# Out:
#                FullTimeGoals
#                        count      mean       std  min  25%  50%  75%  max
# HomeTeam
# Arsenal                 19.0  4.105263  1.448936  0.0  3.5  4.0  5.0  6.0
# Aston Villa             19.0  2.842105  1.500487  1.0  2.0  3.0  3.5  6.0
# Bournemouth             19.0  2.526316  1.576509  0.0  1.5  2.0  3.5  5.0
# Brentford               19.0  2.789474  1.548438  0.0  2.0  2.0  3.5  7.0
# Brighton                19.0  3.052632  2.368161  0.0  1.0  3.0  5.5  7.0
# Chelsea                 19.0  2.052632  1.268143  0.0  1.0  2.0  3.0  4.0
# Crystal Palace          19.0  2.315789  1.668420  0.0  1.5  2.0  3.0  7.0
# Everton                 19.0  2.263158  1.407997  0.0  1.0  2.0  3.0  5.0
# Fulham                  19.0  3.157895  1.740471  0.0  2.5  3.0  4.0  8.0
# Leeds                   19.0  3.315789  2.109572  0.0  2.0  3.0  4.5  7.0
# Leicester               19.0  2.631579  1.422460  0.0  1.0  3.0  4.0  5.0
# ...

# %%
epl_goals[['AwayTeam', 'FullTimeGoals', 'FullTimeGoals_binned']].groupby("AwayTeam").describe()
# Out:
#                FullTimeGoals
#                        count      mean       std  min  25%  50%  75%  max
# AwayTeam
# Arsenal                 19.0  2.789474  1.652572  1.0  1.5  2.0  4.0  6.0
# Aston Villa             19.0  2.263158  1.097578  0.0  2.0  2.0  3.0  4.0
# Bournemouth             19.0  3.157895  2.242597  1.0  1.5  2.0  4.5  9.0
# Brentford               19.0  2.684211  1.827343  0.0  1.5  2.0  4.0  6.0
# Brighton                19.0  3.526316  1.172292  2.0  3.0  3.0  4.0  6.0
# Chelsea                 19.0  2.421053  1.538968  0.0  1.0  2.0  3.5  5.0
# Crystal Palace          19.0  2.368421  1.801559  0.0  1.0  2.0  3.0  6.0
# Everton                 19.0  2.526316  1.466986  0.0  2.0  2.0  3.5  6.0
# Fulham                  19.0  2.526316  1.645479  0.0  1.0  3.0  3.5  5.0
# Leeds                   19.0  3.315789  2.056227  0.0  1.5  3.0  4.5  7.0
# Leicester               19.0  3.631579  2.314460  0.0  2.0  3.0  5.0  8.0
# ...

# %%
epl_goals.query('FullTimeGoals_binned=="low"')[["HomeTeam", "AwayTeam", "FTHG", "FTAG", "FullTimeGoals", "FullTimeGoals_binned"]].groupby("HomeTeam").max()
# Out:
#                  AwayTeam  FTHG  FTAG  FullTimeGoals FullTimeGoals_binned
# HomeTeam
# Arsenal         Newcastle     2     3              3                  low
# Aston Villa        Wolves     3     2              3                  low
# Bournemouth        Wolves     3     3              3                  low
# Brentford          Wolves     3     3              3                  low
# Brighton        Tottenham     3     2              3                  low
# Chelsea            Wolves     3     2              3                  low
# Crystal Palace     Wolves     2     3              3                  low
# Everton            Wolves     3     3              3                  low
# Fulham             Wolves     3     3              3                  low
# Leeds              Wolves     3     2              3                  low
# Leicester          Wolves     2     3              3                  low
# Liverpool          Wolves     2     2              3                  low
# ...

# %%
epl_results.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0

# %%
epl_results.query('HomeTeam=="Man United"').plot(kind='line', y='FTHG', figsize=(10, 5), style='-b', title="Home goals scored by Man United", legend=False)
# Out:
# <AxesSubplot:title={'center':'Home goals scored by Man United'}, xlabel='Date'>

# %% [markdown]
# Upon Plotting the goals scored at home by Man United for the 2022/23 season I can see that the dates were wrongfully input.  The Premier League season starts from August 2022 and ends in May 2023, but in our visualization we are getting the year 2024

# %%
epl_results.query('HomeTeam=="Man United"').reset_index()
# Out:
#          Date    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# 0  2022-07-08  Man United        Brighton     1     2   A     0     2
# 1  2022-08-22  Man United       Liverpool     2     1   H     1     0
# 2  2022-04-09  Man United         Arsenal     3     1   H     1     0
# 3  2022-10-16  Man United       Newcastle     0     0   D     0     0
# 4  2022-10-19  Man United       Tottenham     2     0   H     0     0
# 5  2022-10-30  Man United        West Ham     1     0   H     1     0
# 6  2022-12-27  Man United      Nottingham     3     0   H     2     0
# 7  2023-03-01  Man United     Bournemouth     3     0   H     1     0
# 8  2023-01-14  Man United        Man City     2     1   H     0     0
# 9  2023-04-02  Man United  Crystal Palace     2     1   H     1     0
# 10 2023-08-02  Man United           Leeds     2     2   D     0     1
# 11 2023-02-19  Man United       Leicester     3     0   H     1     0
# ...

# %% [markdown]
# I then use the histogram instead

# %%
import matplotlib.pyplot as plt
epl_results.query('HomeTeam=="Man United"').FTHG.plot(kind='hist', title="Home goals scored by Man United")
plt.xlabel('Home goals scored by Man United')
# Out:
# Text(0.5, 0, 'Home goals scored by Man United')

# %% [markdown]
# With the histogram we can easily pick out the Man United didn't score a single goal at home 2 times and they scored 2 goals the most, doing this 8 times

# %%
epl_results.HomeTeam.unique()
# Out:
# array(['Crystal Palace', 'Fulham', 'Bournemouth', 'Leeds', 'Newcastle',
#        'Tottenham', 'Everton', 'Leicester', 'Man United', 'West Ham',
#        'Aston Villa', 'Arsenal', 'Brighton', 'Man City', 'Southampton',
#        'Wolves', 'Brentford', 'Nottingham', 'Chelsea', 'Liverpool'],
#       dtype=object)

# %%
teams = ['Tottenham','Man United', 'Arsenal', 'Man City', 'Chelsea', 'Liverpool']

# %%
fig, axes = plt.subplots(figsize=(8, 5))

for team in teams:
    data = epl_results.query(f'HomeTeam=="{team}"').FTHG
    if not data.empty:
        data.plot(
            kind='hist',
            ax=axes,
            alpha=0.4,
            label=team,
            legend=True,
            title='Comparing Histograms of goals scored at home by a big 6 club'
        )
plt.xlabel('Goals')
# Out:
# Text(0.5, 0, 'Goals')

# %%
epl_results.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0

# %%
wide_df = epl_results.pivot(columns='HomeTeam', values='FTHG')

# %%
wide_df.head()
# Out:
# HomeTeam    Arsenal  Aston Villa  Bournemouth  Brentford  Brighton  Chelsea  \
# Date
# 2022-01-09      NaN          NaN          NaN        NaN       NaN      NaN
# 2022-01-10      3.0          NaN          0.0        NaN       NaN      NaN
# 2022-02-10      NaN          NaN          NaN        NaN       NaN      NaN
# 2022-03-09      NaN          1.0          NaN        5.0       NaN      2.0
# 2022-03-10      NaN          NaN          NaN        NaN       NaN      NaN
#
# HomeTeam    Crystal Palace  Everton  Fulham  Leeds  Leicester  Liverpool  \
# Date
# 2022-01-09             NaN      NaN     NaN    NaN        0.0        NaN
# 2022-01-10             1.0      NaN     1.0    NaN        NaN        3.0
# 2022-02-10             NaN      NaN     NaN    0.0        NaN        NaN
# 2022-03-09             NaN      0.0     NaN    NaN        NaN        NaN
# 2022-03-10             NaN      NaN     NaN    NaN        4.0        NaN
#
# ...

# %%
wide_df.Arsenal.value_counts()
# Out:
# 3.0    7
# 4.0    4
# 2.0    2
# 5.0    2
# 1.0    2
# 0.0    2
# Name: Arsenal, dtype: int64

# %%
wide_df[teams].plot(kind='hist', subplots=True, layout=(3,2), figsize=(15,7), title='PL GOALS scored at home by the big 6 clubs')
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# From the visualizations it is clear to see that Chelsea was struggling as it had 6 games where it didn't score any goal at home
# Man City's home form was impressive, there was no game when they did not score at home
# Liverpool had 2 games when they performed exceptionally well by scoring 7 and 9
# Tottenham had 1 game when they scored 6 goals as for the rest of the resy of their games most of them they scored only 1 and 2 goals
# Man United had a record 8 games when they scored 2 goals
# Arsenal had 7 games when they scored 3 goals at home making them and City the most in form teams at home in terms of goals scored
# Chelsea was the least in form team at home judging by the goals scored metric

# %%
epl_results.pivot(columns='AwayTeam', values='FTAG')[teams].plot(kind='hist', subplots=True, layout=(3,2), figsize=(15,7), title='PL GOALS scored away by the big 6 clubs')
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# Liverpool and Chelsea did not perform quite well away with the teams not scoring any goals 7 times <br>
# All the teams except Liverpool had more games when they scored only 1 goal

# %%
wide_df.head()
# Out:
# HomeTeam    Arsenal  Aston Villa  Bournemouth  Brentford  Brighton  Chelsea  \
# Date
# 2022-01-09      NaN          NaN          NaN        NaN       NaN      NaN
# 2022-01-10      3.0          NaN          0.0        NaN       NaN      NaN
# 2022-02-10      NaN          NaN          NaN        NaN       NaN      NaN
# 2022-03-09      NaN          1.0          NaN        5.0       NaN      2.0
# 2022-03-10      NaN          NaN          NaN        NaN       NaN      NaN
#
# HomeTeam    Crystal Palace  Everton  Fulham  Leeds  Leicester  Liverpool  \
# Date
# 2022-01-09             NaN      NaN     NaN    NaN        0.0        NaN
# 2022-01-10             1.0      NaN     1.0    NaN        NaN        3.0
# 2022-02-10             NaN      NaN     NaN    0.0        NaN        NaN
# 2022-03-09             NaN      0.0     NaN    NaN        NaN        NaN
# 2022-03-10             NaN      NaN     NaN    NaN        4.0        NaN
#
# ...

# %%
wide_df.Arsenal.value_counts()
# Out:
# 3.0    7
# 4.0    4
# 2.0    2
# 5.0    2
# 1.0    2
# 0.0    2
# Name: Arsenal, dtype: int64

# %%
epl_results.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(epl_results, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:xlabel='FTHG', ylabel='FTHG'>,
#         <AxesSubplot:xlabel='FTAG', ylabel='FTHG'>,
#         <AxesSubplot:xlabel='HTHG', ylabel='FTHG'>,
#         <AxesSubplot:xlabel='HTAG', ylabel='FTHG'>],
#        [<AxesSubplot:xlabel='FTHG', ylabel='FTAG'>,
#         <AxesSubplot:xlabel='FTAG', ylabel='FTAG'>,
#         <AxesSubplot:xlabel='HTHG', ylabel='FTAG'>,
#         <AxesSubplot:xlabel='HTAG', ylabel='FTAG'>],
#        [<AxesSubplot:xlabel='FTHG', ylabel='HTHG'>,
#         <AxesSubplot:xlabel='FTAG', ylabel='HTHG'>,
#         <AxesSubplot:xlabel='HTHG', ylabel='HTHG'>,
#         <AxesSubplot:xlabel='HTAG', ylabel='HTHG'>],
#        [<AxesSubplot:xlabel='FTHG', ylabel='HTAG'>,
#         <AxesSubplot:xlabel='FTAG', ylabel='HTAG'>,
#         <AxesSubplot:xlabel='HTHG', ylabel='HTAG'>,
#         <AxesSubplot:xlabel='HTAG', ylabel='HTAG'>]], dtype=object)

# %%
pl = pd.read_csv('data/epl_results_2022-23.csv')

# %%
pl.head()
# Out:
#          Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0     1
# 1  06/08/2022  12:30          Fulham    Liverpool     2     2   D     1     0
# 2  06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1     0
# 3  06/08/2022  15:00           Leeds       Wolves     2     1   H     1     1
# 4  06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0     0
#
#   HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   A  ...   2    2  16  11   3   5   1   2   0   0
# 1   H  ...   3    4   7   9   4   4   2   0   0   0
# 2   H  ...   3    2  18  16   5   5   3   3   0   0
# 3   D  ...   4    6  13   9   6   4   2   0   0   0
# 4   D  ...  10    0   9  14  11   1   0   3   0   0
#
# [5 rows x 23 columns]

# %%
pl.columns
# Out:
# Index(['Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
united_home = epl_results.query('HomeTeam=="Man City"')

# %%
united_home['home_binned'] = pd.cut(
    united_home.FTHG, bins=3, labels=['low', 'med', 'high']
)
# Out:
# C:\Users\Che\AppData\Local\Temp\ipykernel_10792\2730522213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   united_home['home_binned'] = pd.cut(

# %%
united_home.home_binned.value_counts().plot(kind='bar', figsize=(10,5), title='Man United Home Goals ')
# Out:
# <AxesSubplot:title={'center':'Man United Home Goals '}>

# %%
epl_results[['HomeTeam', 'FTHG']].query(f'HomeTeam=={teams}').groupby('HomeTeam').boxplot(figsize=(15, 8), subplots=False)
# Out:
# <AxesSubplot:>

# %%
epl_results[['AwayTeam', 'FTAG']].query(f'AwayTeam=={teams}').groupby('AwayTeam').boxplot(figsize=(15, 8), subplots=False)
# Out:
# <AxesSubplot:>

# %%
epl_results.head()
# Out:
#                   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG
# Date
# 2022-05-08  Crystal Palace      Arsenal     0     2   A     0     1
# 2022-06-08          Fulham    Liverpool     2     2   D     1     0
# 2022-06-08     Bournemouth  Aston Villa     2     0   H     1     0
# 2022-06-08           Leeds       Wolves     2     1   H     1     1
# 2022-06-08       Newcastle   Nottingham     2     0   H     0     0

# %%
pl.head()
# Out:
#          Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0     1
# 1  06/08/2022  12:30          Fulham    Liverpool     2     2   D     1     0
# 2  06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1     0
# 3  06/08/2022  15:00           Leeds       Wolves     2     1   H     1     1
# 4  06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0     0
#
#   HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   A  ...   2    2  16  11   3   5   1   2   0   0
# 1   H  ...   3    4   7   9   4   4   2   0   0   0
# 2   H  ...   3    2  18  16   5   5   3   3   0   0
# 3   D  ...   4    6  13   9   6   4   2   0   0   0
# 4   D  ...  10    0   9  14  11   1   0   3   0   0
#
# [5 rows x 23 columns]

# %%
pl.plot(kind='scatter', x='HY', y='HR', title='Corners vs Goals Scored at Home')
# Out:
# <AxesSubplot:title={'center':'Corners vs Goals Scored at Home'}, xlabel='HY', ylabel='HR'>
